# %%
import pandas as pd
import Tools
import hubspot as hubspot
from hubspot.crm.contacts import BatchInputSimplePublicObjectInputForCreate, ApiException
from hubspot.crm.contacts import BatchInputSimplePublicObjectBatchInput, ApiException

HubSpotDataPipeline=Tools.HubSpotDataPipeline
# Initialize the HubSpot data pipeline with API key
pipeline = HubSpotDataPipeline(api_key_to="HUBSPOT_API_KEY",api_key_from="HUBSPOT_API_KEY")

# %% [markdown]
# 1. Extract Data:
#    - This block calls the extract() method from pipeline to retrieve contact data, storing it in data_list.
#    - The data is then converted into a DataFrame (data_frame) for easier handling.
#    - The DataFrame is saved to a CSV file named "contacts_data_collect.csv" for record-keeping or further analysis.

# %%
# Extract data
data_list = pipeline.extract()
data_frame = pd.DataFrame(data_list)
print(data_frame)
# Save the extracted data
data_frame.to_csv("contacts_data_collect.csv", index=False)
print("Data saved to contacts_data_collect.csv")
# Out:
#        firstname     lastname  \
# 0            Zoe         Owen
# 1           Zara      Rodwell
# 2           Zara     Freeburn
# 3         Winnie       Walter
# 4            Zoe         Owen
# 5           Zara     Oldfield
# 6           Zara     Freeburn
# 7           Zara      Rodwell
# 8           Zara     Oldfield
# 9         Willow       Morris
# 10        Willow         Nash
# 11        Willow         Nash
# 12        Willow       Morris
# 13        Winnie      Bristow
# 14        Willow        Jones
# 15        Winnie       Walter
# 16        Winnie      Bristow
# 17       William   Wooldridge
# 18       William    Wilkinson
# 19       William         Tate
# 20       William   Wooldridge
# 21       William    Wilkinson
# 22       William      Webster
# 23       William      Webster
# 24       William    Wilkinson
# 25        Willow        Jones
# 26       William      Neville
# 27       William        Nobbs
# 28       William         Tate
# 29       William      Russell
# 30       William        Nobbs
# 31       William      Russell
# 32       William       Murray
# 33       William      Neville
# 34       William      Sanchez
# 35       William      Sanchez
# 36       William          Lee
# 37       William      Hammond
# 38       William       Murray
# 39       William         Gray
# 40       William          Lee
# 41       William      Hammond
# 42       William         Gray
# 43       William       Howard
# 44       William          Lee
# 45       William       Howard
# 46       William       Butler
# 47       William     Drummond
# 48       William      Ellison
# 49       William        Booth
# 50       William     Drummond
# 51       William        Booth
# 52       William      Ellison
# 53       William        Adams
# 54       William        Adams
# 55       William       Butler
# 56         Wendy       Farmer
# 57          Wade      Webster
# 58          Wade       Wilton
# 59          Wade       Watson
# 60          Wade      Webster
# 61         Wendy       Farmer
# 62         Wendy        Allen
# 63         Wendy        Allen
# 64          Wade       Watson
# 65          Wade       Wilton
# 66          Wade     Robinson
# 67          Wade       Squire
# 68          Wade     Thompson
# 69          Wade       Squire
# 70          Wade     Robinson
# 71          Wade      Tennant
# 72          Wade      Tennant
# 73          Wade       Talbot
# 74          Wade     Thompson
# 75          Wade       Talbot
# 76          Wade     Hamilton
# 77          Wade    Partridge
# 78          Wade      Olivier
# 79          Wade      Olivier
# 80          Wade       Norris
# 81          Wade     Hamilton
# 82          Wade        Logan
# 83          Wade        Gates
# 84          Wade    Partridge
# 85          Wade       Norris
# 86          Wade        Logan
# 87          Wade       Garner
# 88          Wade    Alexander
# 89          Wade     Anderson
# 90          Wade   Broomfield
# 91          Wade       Garner
# 92          Wade        Evans
# 93          Wade        Evans
# 94          Wade   Broomfield
# 95          Wade        Gates
# 96          Wade    Alexander
# 97          Wade     Anderson
# 98          Wade    Alexander
# 99        Vivian      Russell
# 100       Violet        Moran
# 101         Vera        Payne
# 102         Vera        Payne
# 103         Vera        Janes
# 104        Vicky     Morrison
# 105         Vera        Payne
# 106       Vivian      Russell
# 107       Violet        Moran
# 108        Vicky     Morrison
# 109      Vanessa       Holmes
# 110      Vanessa        Evans
# 111      Vanessa       Russel
# 112      Vanessa       Holmes
# 113      Vanessa         Neal
# 114         Vera        Janes
# 115      Vanessa         Neal
# 116      Vanessa       Gordon
# 117      Vanessa       Russel
# 118      Vanessa       Gordon
# 119    Valentina       Bishop
# 120        Tyson         Wise
# 121    Valentina      Huggins
# 122      Vanessa        Evans
# 123    Valentina       Bishop
# 124      Vanessa      Doherty
# 125        Tyson         Wise
# 126    Valentina      Huggins
# 127      Vanessa      Doherty
# 128        Tyson     Saunders
# 129        Tyson      Simmons
# 130        Tyson     Saunders
# 131        Tyson     Reynolds
# 132        Tyson        Speed
# 133        Tyson     Reynolds
# 134        Tyson      Simmons
# 135        Tyson        Speed
# 136        Tyson        Raven
# 137        Tyson         Wise
# 138        Tyson        Nobbs
# 139        Tyson       Nelson
# 140         None         None
# 141        Tyson        Raven
# 142        Tyson      Mullins
# 143         None         None
# 144         None         None
# 145        Tyson       Newman
# 146        Tyson      Mullins
# 147        Tyson       Nelson
# 148        Tyson        Nobbs
# 149        Tyson          Lee
# 150        Tyson          Lee
# 151        Tyson         Kidd
# 152        Tyson       Martin
# 153        Tyson     Matthews
# 154        Tyson       Martin
# 155        Tyson     Matthews
# 156        Tyson        Lloyd
# 157        Tyson        Lloyd
# 158        Tyson        Kelly
# 159        Tyson         Hall
# 160        Tyson         Hall
# 161        Tyson         Hunt
# 162        Tyson        Flack
# 163        Tyson        Kelly
# 164        Tyson         Kidd
# 165        Tyson       Hilton
# 166        Tyson       Hilton
# 167        Tyson         Hunt
# 168        Tyler       Wilson
# 169        Tyson     Donnelly
# 170        Tyson     Campbell
# 171        Tyson       Butler
# 172        Tyson        Brock
# 173        Tyson     Donnelly
# 174        Tyson        Brock
# 175        Tyson       Butler
# 176        Tyson        Flack
# 177        Tyson        Brock
# 178        Tyson     Campbell
# 179        Tyler       Wilson
# 180        Tyler        Scott
# 181        Tyler         Wade
# 182        Tyler         West
# 183        Tyler         Wade
# 184        Tyler       Ulyatt
# 185        Tyler         Vane
# 186        Tyler         Vane
# 187        Tyler       Ulyatt
# 188        Tyler         West
# 189        Tyler       Oakley
# 190        Tyler       Parker
# 191        Tyler       Nayler
# 192        Tyler       Oakley
# 193        Tyler        Scott
# 194        Tyler         Ryan
# 195        Tyler       Parker
# 196        Tyler         Pond
# 197        Tyler         Pond
# 198        Tyler         Ryan
# 199        Tyler       Nanton
# 200        Tyler       Nayler
# 201        Tyler         Hunt
# 202        Tyler        James
# 203        Tyler      Kennedy
# 204        Tyler         Hunt
# 205        Tyler        James
# 206        Tyler        Kelly
# 207        Tyler     Harrison
# 208        Tyler       Nanton
# 209        Tyler        Kelly
# 210        Tyler      Kennedy
# 211        Tyler        Evans
# 212        Tyler     Harrison
# 213        Tyler      Funnell
# 214        Tyler        Evans
# 215        Tyler        Evans
# 216        Tyler      Ellison
# 217        Tyler      Ellison
# 218        Tyler      Egerton
# 219        Tyler      Funnell
# 220        Tyler      Bennett
# 221        Tyler       Cadman
# 222        Tyler       Brooks
# 223        Tyler      Baldwin
# 224        Tyler      Baldwin
# 225        Tyler       Brooks
# 226        Tyler      Egerton
# 227        Tyler      Bennett
# 228        Tyler       Cadman
# 229       Trisha   Whitehouse
# 230         Tony        Walsh
# 231         Tony       Warden
# 232         Tony       Walker
# 233         Tony       Warden
# 234       Trisha     Matthews
# 235         Tony        Yoman
# 236         Tony        Yoman
# 237       Trisha   Whitehouse
# 238         Tony        Walsh
# 239       Trisha     Matthews
# 240         Tony        Rixon
# 241         Tony        Rixon
# 242         Tony     Rainford
# 243         Tony       Potter
# 244         Tony      Redfern
# 245         Tony     Rainford
# 246         Tony      Redfern
# 247         Tony       Walker
# 248         Tony       Walker
# 249         Tony        Rixon
# 250         Tony     Marshall
# 251         Tony         Hope
# 252         Tony     Marshall
# 253         Tony        James
# 254         Tony      Nicolas
# 255         Tony        James
# 256         Tony         Hope
# 257         Tony      Nicolas
# 258         Tony       Potter
# 259         Tony     Campbell
# 260         Tony     Hamilton
# 261         Tony         Gray
# 262         Tony     Hamilton
# 263         Tony     Campbell
# 264         Tony        Grady
# 265         Tony        Grady
# 266         Tony      Gilbert
# 267         Tony      Gilbert
# 268         Tony         Gray
# 269          Tom      Weasley
# 270          Tom       Vinton
# 271         Tony       Bryant
# 272          Tom      Townend
# 273          Tom       Vinton
# 274         Tony       Bryant
# 275          Tom     Thompson
# 276          Tom     Thompson
# 277          Tom     Thompson
# 278          Tom      Weasley
# 279          Tom      Townend
# 280          Tom        Swift
# 281          Tom      Stewart
# 282          Tom        Stone
# 283          Tom      Stewart
# 284          Tom         Salt
# 285          Tom         Salt
# 286          Tom         Snow
# 287          Tom     Thompson
# 288          Tom         Snow
# 289          Tom        Swift
# 290          Tom        Stone
# 291          Tom         Owen
# 292          Tom       Parker
# 293          Tom         Owen
# 294          Tom       Osmond
# 295          Tom      Russell
# 296          Tom       Parker
# 297          Tom       Osmond
# 298          Tom      Russell
# 299          Tom       Morris
# 300          Tom       Morris
# 301          Tom     Mitchell
# 302          Tom       Morris
# 303          Tom         Keys
# 304          Tom        James
# 305          Tom     Marshall
# 306          Tom        James
# 307          Tom        James
# 308          Tom     Marshall
# 309          Tom     Mitchell
# 310          Tom         Keys
# 311          Tom     Mitchell
# 312          Tom         Keys
# 313          Tom       Archer
# 314          Tom    Griffiths
# 315         Thea        Allen
# 316          Tom    Griffiths
# 317          Tom      Ballard
# 318      Tiffany      Shields
# 319      Tiffany      Shields
# 320          Tom       Harvey
# 321          Tom       Archer
# 322          Tom       Harvey
# 323          Tom      Ballard
# 324         Tara       Pearce
# 325         Tess    Sylvester
# 326         Thea        Allen
# 327         Tess       Jacobs
# 328         Tara     Phillips
# 329       Taylor        Booth
# 330         Tess    Sylvester
# 331         Tess       Jacobs
# 332       Taylor        Booth
# 333         Tara     Phillips
# 334        Tania      Cattell
# 335        Tania       Graham
# 336       Sydney         Ward
# 337        Tania      Cattell
# 338       Sydney         Ward
# 339        Tania         Lane
# 340        Tania         Lane
# 341        Tania       Graham
# 342         Tara       Pearce
# 343       Summer    Griffiths
# 344        Susan       Wright
# 345        Susan       Wright
# 346       Summer        Price
# 347       Summer    Griffiths
# 348        Susan        Evans
# 349       Summer        Price
# 350        Susan        Evans
# 351       Sydney        Walsh
# 352       Sydney        Walsh
# 353       Summer       Graham
# 354       Summer      Addison
# 355    Stephanie     Rowlands
# 356       Summer       Graham
# 357    Stephanie       Cooper
# 358       Summer      Addison
# 359    Stephanie     Rowlands
# 360    Stephanie       Clarke
# 361    Stephanie       Cooper
# 362    Stephanie       Clarke
# 363       Stella        Avery
# 364       Stella        Dixon
# 365       Stella        Dixon
# 366       Stella      Stewart
# 367        Stacy     Sinclair
# 368        Stacy      Whittle
# 369       Stella        Avery
# 370       Stella      Stewart
# 371        Stacy      Whittle
# 372        Stacy     Sinclair
# 373        Stacy     Antcliff
# 374        Stacy       London
# 375        Stacy       London
# 376        Sofia      Preston
# 377        Stacy     Antcliff
# 378        Sofie      Spencer
# 379        Sofia      Preston
# 380        Sofie      Spencer
# 381        Sofie        Walsh
# 382        Sofie        Walsh
# 383       Sloane        Uddin
# 384       Sloane      Stevens
# 385        Sofia      Johnson
# 386       Sloane        Uddin
# 387        Sofia      Johnson
# 388        Sofia   Harrington
# 389       Sloane      Stevens
# 390        Sofia   Harrington
# 391       Sloane       Knight
# 392       Skylar      Bentley
# 393       Sloane       Knight
# 394       Sienna    Stevenson
# 395       Sloane   Harrington
# 396       Skylar      Bentley
# 397       Sloane   Harrington
# 398       Sienna    Stevenson
# 399       Sienna       Jarvis
# 400       Shelby       Murray
# 401       Shelby       Taylor
# 402       Sienna       Jarvis
# 403       Shelby       Taylor
# 404       Sienna         Shaw
# 405       Sienna         Shaw
# 406         Shay         Kaur
# 407       Sharon   Richardson
# 408       Shelby       Little
# 409       Shelby       Murray
# 410       Sharon     Phillips
# 411         Shay         Kaur
# 412       Sharon          Lee
# 413       Sharon     Phillips
# 414       Shelby       Little
# 415       Sharon   Richardson
# 416       Selena         Ross
# 417      Shannon      Everett
# 418       Selena         Ross
# 419      Shannon   Richardson
# 420       Selena       Norris
# 421       Sharon          Lee
# 422      Shannon   Richardson
# 423       Selena       Norris
# 424       Selena    Ainsworth
# 425      Shannon      Everett
# 426    Sebastian    Wilkinson
# 427    Sebastian    Wilkinson
# 428    Sebastian       Uttley
# 429    Sebastian       Wright
# 430    Sebastian       Wright
# 431       Selena    Ainsworth
# 432    Sebastian       Wilton
# 433    Sebastian       Wilton
# 434    Sebastian       Uttley
# 435    Sebastian      Stewart
# 436    Sebastian     Thompson
# 437    Sebastian        Umney
# 438    Sebastian        Umney
# 439    Sebastian      Tennant
# 440    Sebastian      Stewart
# 441    Sebastian     Thompson
# 442    Sebastian     Thompson
# 443    Sebastian        Roman
# 444    Sebastian      Tennant
# 445    Sebastian       Parker
# 446    Sebastian        Roman
# 447         None         None
# 448    Sebastian       Parker
# 449    Sebastian       Palmer
# 450         None         None
# 451    Sebastian       Parker
# 452    Sebastian       Parker
# 453    Sebastian       Parker
# 454    Sebastian       Parker
# 455    Sebastian       Morris
# 456    Sebastian       Murphy
# 457    Sebastian       Murphy
# 458    Sebastian        Lewis
# 459    Sebastian      Kennedy
# 460    Sebastian        Lewis
# 461    Sebastian       Palmer
# 462    Sebastian       Morris
# 463    Sebastian       Murphy
# 464    Sebastian     Flanders
# 465    Sebastian        Drake
# 466    Sebastian         Hope
# 467         None         None
# 468    Sebastian         Hope
# 469         None         None
# 470    Sebastian         Hope
# 471    Sebastian      Kennedy
# 472    Sebastian     Freeburn
# 473    Sebastian     Flanders
# 474    Sebastian     Freeburn
# 475    Sebastian       Benson
# 476     Scarlett       Watson
# 477    Sebastian      Attwood
# 478    Sebastian      Allwood
# 479    Sebastian       Benson
# 480    Sebastian      Bennett
# 481    Sebastian        Drake
# 482    Sebastian      Attwood
# 483    Sebastian      Allwood
# 484    Sebastian      Bennett
# 485     Savannah        Evans
# 486     Savannah        Evans
# 487     Scarlett        Flack
# 488        Sasha       Graham
# 489     Scarlett        Flack
# 490     Scarlett       Watson
# 491        Sarah       Radley
# 492     Savannah      Vaughan
# 493        Sasha       Graham
# 494        Sarah       Radley
# 495     Savannah      Vaughan
# 496         Sara       Tailor
# 497         Sara       Tailor
# 498         Sara      Stanley
# 499         Sara      Stanley
# 500         Sara        Pratt
# 501         Sara       Potter
# 502         Sage        Dixon
# 503       Samara        Kelly
# 504     Samantha      Furnell
# 505         Sara       Potter
# 506         Sara        Pratt
# 507       Samara        Kelly
# 508     Samantha      Furnell
# 509      Sabrina       Styles
# 510        Rylee         Ryan
# 511      Sabrina      Simmons
# 512         Sage        Dixon
# 513        Rylee         Lyon
# 514      Sabrina      Simmons
# 515      Sabrina       Styles
# 516        Sadie     Whitmore
# 517        Sadie     Whitmore
# 518        Rylee         Ryan
# 519         Ryan       Welsch
# 520        Rylee        Jones
# 521         Ryan       Welsch
# 522         None         None
# 523        Rylee        Jones
# 524         Ryan      Willson
# 525         None         None
# 526         Ryan      Willson
# 527        Rylee         Lyon
# 528         None         None
# 529         Ryan      Upsdell
# 530         None         None
# 531         Ryan      Upsdell
# 532         None         None
# 533         Ryan     Shepherd
# 534         Ryan      Upsdell
# 535         None         None
# 536         Ryan         Tait
# 537         Ryan     Shepherd
# 538         Ryan         Tait
# 539         None         None
# 540         Ryan        James
# 541         Ryan         Rowe
# 542         Ryan      Nielson
# 543         Ryan       Miller
# 544         Ryan       Samuel
# 545         Ryan       Miller
# 546         Ryan       Samuel
# 547         Ryan      Nielson
# 548         Ryan        James
# 549         Ryan         Rowe
# 550         Ryan        Ellis
# 551         Ryan      Eddison
# 552         Ryan        Ebden
# 553         Ryan      Eddison
# 554         Ryan        Ebden
# 555         Ryan        Ellis
# 556         Ryan        Hobbs
# 557         Ryan         Hill
# 558         Ryan         Hill
# 559         Ryan        Hobbs
# 560         Ryan        Ebden
# 561         Ryan       Carter
# 562         Ryan         Cobb
# 563         Ryan    Blackwall
# 564         Ryan         Cobb
# 565         Ryan         Cobb
# 566         Ryan    Blackwall
# 567         Ryan      Corbett
# 568         Ryan       Carter
# 569         Ryan      Corbett
# 570         Ryan       Carter
# 571       Russel         Shaw
# 572         Ruth       Morley
# 573       Russel      Wheeler
# 574         Ruth       Morley
# 575       Russel         Shaw
# 576       Russel         Wade
# 577       Russel      Wheeler
# 578       Russel      Russell
# 579       Russel         Wade
# 580       Russel      Russell
# 581       Russel      Mcguire
# 582       Russel     Robinson
# 583       Russel       Milner
# 584       Russel       Parker
# 585       Russel       Parker
# 586       Russel       Milner
# 587       Russel     Robinson
# 588       Russel      Mcguire
# 589       Russel     Rothwell
# 590       Russel     Rothwell
# 591       Russel    Goldsmith
# 592       Russel       Knight
# 593       Russel       Knight
# 594       Russel    Goldsmith
# 595       Russel       Knight
# 596       Russel    Griffiths
# 597       Russel       Foxley
# 598       Russel    Griffiths
# 599       Russel      Edmonds
# 600       Russel       Foxley
# 601       Russel     Driscoll
# 602       Russel     Driscoll
# 603       Russel      Edmonds
# 604       Russel         Cobb
# 605       Russel      Collins
# 606       Russel      Corbett
# 607       Russel         Cobb
# 608        Rufus       Wright
# 609       Russel         Dann
# 610       Russel         Dann
# 611       Russel      Collins
# 612        Rufus       Wright
# 613       Russel      Corbett
# 614        Rufus     Whitmore
# 615        Rufus        Stark
# 616        Rufus        Stark
# 617        Rufus     Thornton
# 618        Rufus        Stark
# 619        Rufus      Summers
# 620        Rufus        Walsh
# 621        Rufus     Whitmore
# 622        Rufus     Thornton
# 623        Rufus      Summers
# 624        Rufus        Walsh
# 625        Rufus        Roman
# 626        Rufus        Roman
# 627        Rufus       Samuel
# 628        Rufus       Samuel
# 629        Rufus         Shaw
# 630        Rufus     Reynolds
# 631        Rufus         Shaw
# 632        Rufus     Reynolds
# 633        Rufus        Roman
# 634        Rufus      Nielson
# 635        Rufus      Quinton
# 636        Rufus      Quinton
# 637        Rufus       Palmer
# 638        Rufus      Quinton
# 639        Rufus     Reynolds
# 640        Rufus      Nielson
# 641        Rufus       Palmer
# 642        Rufus         Noon
# 643        Rufus         Noon
# 644        Rufus       Murray
# 645        Rufus     Gonzales
# 646        Rufus       Morris
# 647        Rufus         Lane
# 648        Rufus     Gonzales
# 649        Rufus       Murray
# 650        Rufus         Lane
# 651        Rufus       Morris
# 652        Rufus       Morris
# 653        Rufus       Murray
# 654        Rufus        Abbot
# 655        Rufus      Furnell
# 656        Rufus      Farrant
# 657        Rufus       Cadman
# 658        Rufus       Cadman
# 659        Rufus        Giles
# 660        Rufus        Giles
# 661        Rufus      Farrant
# 662        Rufus        Abbot
# 663        Rufus      Furnell
# 664         Ruby     Donnelly
# 665         Ruby        Terry
# 666         Ruby       Turner
# 667         Ruby       Turner
# 668        Rowan      Stewart
# 669        Rowan      Stewart
# 670         Ruby     Donnelly
# 671         Ruby        Terry
# 672        Rowan      Stewart
# 673        Rowan      Stewart
# 674     Rosemary        Dixon
# 675     Rosemary        Dixon
# 676     Rosemary        Vince
# 677        Rosie        Umney
# 678        Rowan    Robertson
# 679        Rosie        Umney
# 680        Rosie       Graham
# 681        Rosie       Graham
# 682        Rowan    Robertson
# 683     Rosemary        Vince
# 684      Rosalyn         Lane
# 685      Rosalyn      Needham
# 686      Rosalyn       Murray
# 687         Rose        Kelly
# 688      Rosalyn       Bailey
# 689         Rose        Kelly
# 690      Rosalyn         Lane
# 691      Rosalyn      Needham
# 692      Rosalyn       Murray
# 693      Rosalyn       Bailey
# 694      Rosalee      Farrell
# 695      Rosalie      Johnson
# 696      Rosalie       Gordon
# 697      Rosalie       Gordon
# 698      Rosalie      Johnson
# 699      Rosalee      Farrell
# 700      Rosalee       Bryson
# 701      Rosalee       Bryson
# 702         Rosa       Larsen
# 703         Rosa       Larsen
# 704      Rosalee      Clayton
# 705      Rosalee      Clayton
# 706         Rosa         Hope
# 707       Ronald       Walker
# 708         Rosa       Harvey
# 709       Ronald       Wigley
# 710       Ronald        Yates
# 711       Ronald        Yates
# 712         Rosa       Harvey
# 713       Ronald       Wigley
# 714       Ronald       Walker
# 715         Rosa         Hope
# 716       Ronald        Sloan
# 717       Ronald     Villiger
# 718       Ronald     Saunders
# 719       Ronald     Villiger
# 720       Ronald      Stevens
# 721       Ronald     Truscott
# 722       Ronald     Truscott
# 723       Ronald      Stevens
# 724       Ronald        Sloan
# 725       Ronald     Saunders
# 726       Ronald       Nurton
# 727       Ronald    Robertson
# 728       Ronald     Rothwell
# 729       Ronald        Reyes
# 730       Ronald    Robertson
# 731       Ronald     Rothwell
# 732       Ronald        Olson
# 733       Ronald        Olson
# 734       Ronald        Reyes
# 735       Ronald      Hopkins
# 736       Ronald      Hopkins
# 737       Ronald       Nurton
# 738       Ronald        Mould
# 739       Ronald       Mooney
# 740       Ronald      Hopkins
# 741       Ronald       Jenkin
# 742       Ronald        Mould
# 743       Ronald       Mooney
# 744       Ronald       Jenkin
# 745       Ronald         Cork
# 746       Ronald       Clarke
# 747       Ronald      Douglas
# 748       Ronald       Clarke
# 749       Ronald         Cork
# 750       Ronald      Douglas
# 751       Ronald      Douglas
# 752       Ronald       Clarke
# 753       Ronald       Groves
# 754       Ronald       Groves
# 755       Ronald      Attwood
# 756       Ronald       Bishop
# 757       Ronald       Bryant
# 758       Ronald      Bentley
# 759       Ronald       Bryant
# 760       Ronald       Clarke
# 761       Ronald       Bishop
# 762       Ronald      Attwood
# 763       Ronald       Ashley
# 764       Ronald      Bentley
# 765          Ron        Wilde
# 766       Ronald     Antcliff
# 767       Ronald     Antcliff
# 768       Ronald       Ashley
# 769          Ron     Williams
# 770          Ron        Wilde
# 771          Ron         Ward
# 772          Ron         Ward
# 773          Ron     Williams
# 774          Ron     Mitchell
# 775          Ron         Salt
# 776          Ron      Stewart
# 777          Ron     Mitchell
# 778          Ron       Leslie
# 779          Ron    Partridge
# 780          Ron         Salt
# 781          Ron         Salt
# 782          Ron      Stewart
# 783          Ron    Partridge
# 784          Ron       Holmes
# 785        Roger       Wright
# 786          Ron         Coll
# 787          Ron       Leslie
# 788          Ron       Holmes
# 789          Ron         Coll
# 790        Roger       Wright
# 791          Ron        Abbot
# 792          Ron        Abbot
# 793        Roger     Varndell
# 794        Roger     Varndell
# 795        Roger       Turner
# 796        Roger       Turner
# 797        Roger       Thomas
# 798        Roger       Turner
# 799        Roger      Simpson
# 800        Roger         Tait
# 801        Roger       Thomas
# 802        Roger      Simpson
# 803        Roger         Tait
# 804        Roger        Steer
# 805        Roger        Steer
# 806        Roger         Shaw
# 807        Roger         Reid
# 808        Roger   Richardson
# 809        Roger     Robinson
# 810        Roger        Reese
# 811        Roger   Richardson
# 812        Roger     Robinson
# 813        Roger     Robinson
# 814        Roger         Shaw
# 815        Roger         Reid
# 816        Roger        Reese
# 817        Roger      Overson
# 818         None         None
# 819        Roger        Jones
# 820         None         None
# 821         None         None
# 822        Roger      Overson
# 823        Roger       Holmes
# 824        Roger       Holmes
# 825        Roger        Jones
# 826        Roger        Jones
# 827        Rocco     Whitmore
# 828        Rocco       Watson
# 829        Rocco       Watson
# 830        Rocco     Whitmore
# 831        Rocco       Weston
# 832        Roger       Brooks
# 833        Rocco       Weston
# 834        Rocco      Weasley
# 835        Rocco      Weasley
# 836        Roger       Brooks
# 837        Rocco        Tyler
# 838        Rocco        Trent
# 839        Rocco    Underhill
# 840        Rocco      Rycroft
# 841        Rocco    Underhill
# 842        Rocco      Rycroft
# 843        Rocco        Tyler
# 844        Rocco      Tyrrell
# 845        Rocco        Trent
# 846        Rocco      Tyrrell
# 847        Rocco      Poulton
# 848         None         None
# 849        Rocco      Pickard
# 850        Rocco       Redden
# 851        Rocco       Palmer
# 852        Rocco      Poulton
# 853        Rocco      Pickard
# 854        Rocco       Palmer
# 855         None         None
# 856         None         None
# 857        Rocco       Redden
# 858        Rocco       Morgan
# 859        Rocco        Moore
# 860         None         None
# 861        Rocco       Palmer
# 862        Rocco        Moore
# 863        Rocco       Palmer
# 864        Rocco       Martin
# 865        Rocco       Martin
# 866        Rocco       Morgan
# 867        Rocco      Hepburn
# 868         None         None
# 869        Rocco        Grady
# 870        Rocco      Doherty
# 871        Rocco       Hudson
# 872        Rocco       Hudson
# 873         None         None
# 874        Rocco      Hepburn
# 875        Rocco      Doherty
# 876        Rocco        Grady
# 877        Rocco       Martin
# 878        Rocco        Boyle
# 879        Rocco     Anderson
# 880         Rita    Goldsmith
# 881        Rocco        Boyle
# 882        Rocco      Dempsey
# 883        Robyn       Murray
# 884        Rocco      Dempsey
# 885         Rita     Reynolds
# 886        Rocco     Anderson
# 887         Rita     Reynolds
# 888        Robyn       Murray
# 889      Rihanna      Randall
# 890      Rihanna        Lucas
# 891         Rita    Goldsmith
# 892      Rihanna        White
# 893      Rihanna         Kaur
# 894      Rihanna      Randall
# 895      Rihanna         Kaur
# 896      Rihanna        Lucas
# 897      Rihanna    Griffiths
# 898      Rihanna        White
# 899      Rihanna         Drew
# 900      Rihanna         Drew
# 901      Rihanna    Griffiths
# 902         Rick       Ramsey
# 903         Rick       Wright
# 904         Rick       Palmer
# 905         Rick       Wright
# 906         Rick        Scott
# 907         Rick        Scott
# 908         Rick     Oldfield
# 909         Rick       Wright
# 910         Rick       Ramsey
# 911         Rick       Palmer
# 912         Rick       Martin
# 913         Rick       Oakley
# 914         Rick        Glynn
# 915         Rick        Mason
# 916         Rick       Graham
# 917         Rick       Graham
# 918         Rick       Oakley
# 919         Rick       Martin
# 920         Rick     Oldfield
# 921         Rick        Mason
# 922         Rick        Dwyer
# 923         Rick       Connor
# 924         Rick      Farrell
# 925         Rick      Farrell
# 926         Rick        Dwyer
# 927         Rick       Cooper
# 928         Rick        Glynn
# 929         Rick       Cooper
# 930         Rick       Connor
# 931         Rick      Chapman
# 932         Rhea        Baker
# 933         Rick        Bowen
# 934        Renee     Saunders
# 935         Rick        Bowen
# 936        Renee     Saunders
# 937        Renee        Reese
# 938         Rhea        Baker
# 939         Rick      Chapman
# 940         Rick        Bowen
# 941         Remy       Morris
# 942         Remy       Wright
# 943         Remy       Morris
# 944        Renee       Parker
# 945         Remy         Pond
# 946        Renee        Reese
# 947        Renee        Kelly
# 948        Renee       Parker
# 949        Renee        Kelly
# 950         Remy       Wright
# 951         Remy         Pond
# 952         Remy       Camden
# 953         Remy      Mcneill
# 954         Remy       Cadman
# 955         Remy       Camden
# 956         Remy      Mcneill
# 957       Regina    Blackwall
# 958       Regina       Hooper
# 959         Remy       Cadman
# 960       Regina       Hooper
# 961      Rebecca       Powell
# 962      Rebecca        Jones
# 963      Rebecca       Parker
# 964      Rebecca       Powell
# 965       Raquel        Abbot
# 966       Raquel       Powell
# 967      Rebecca       Parker
# 968      Rebecca        Jones
# 969       Regina    Blackwall
# 970       Raquel       Powell
# 971       Raquel        Abbot
# 972        Ramon       Wilson
# 973        Ramon         West
# 974        Ramon         Yang
# 975        Ramon       Wilson
# 976        Ramon       Wilson
# 977        Ramon       Wilson
# 978        Ramon      Widdows
# 979        Ramon      Widdows
# 980        Ramon         Yang
# 981        Ramon         West
# 982        Ramon       Victor
# 983        Ramon      Stewart
# 984        Ramon       Victor
# 985        Ramon      Stewart
# 986        Ramon        Tobin
# 987        Ramon      Roberts
# 988        Ramon      Roberts
# 989        Ramon        Price
# 990        Ramon        Tobin
# 991        Ramon         West
# 992         None         None
# 993        Ramon       Powell
# 994        Ramon        Price
# 995         None         None
# 996        Ramon      Preston
# 997         None         None
# 998        Ramon      Preston
# 999        Ramon       Powell
# 1000       Ramon        Patel
# 1001       Ramon         Long
# 1002       Ramon        Patel
# 1003       Ramon         Long
# 1004       Ramon     Hamilton
# 1005       Ramon        Ebden
# 1006       Ramon     Forester
# 1007       Ramon       Groves
# 1008       Ramon     Hamilton
# 1009       Ramon        Leigh
# 1010       Ramon     Forester
# 1011       Ramon       Groves
# 1012       Ramon        Leigh
# 1013       Ramon        Ebden
# 1014       Ramon       Coates
# 1015       Quinn         Hill
# 1016       Ramon       Coates
# 1017       Ramon      Downing
# 1018     Rachael        Allen
# 1019     Rachael        Allen
# 1020       Ramon      Downing
# 1021       Quinn         Hill
# 1022       Ramon       Coates
# 1023      Phoebe        Drake
# 1024      Phoebe        Drake
# 1025       Piper         Rowe
# 1026   Priscilla     Chappell
# 1027     Phillip      Weasley
# 1028     Phillip      Weasley
# 1029       Quinn    Armstrong
# 1030       Piper         Rowe
# 1031   Priscilla     Chappell
# 1032       Quinn    Armstrong
# 1033     Phillip        Umney
# 1034     Phillip      Thomson
# 1035     Phillip      Thomson
# 1036     Phillip     Thompson
# 1037     Phillip         Ross
# 1038     Phillip        Umney
# 1039     Phillip       Samuel
# 1040     Phillip     Thompson
# 1041     Phillip         Ross
# 1042     Phillip       Samuel
# 1043     Phillip       Norton
# 1044     Phillip        Moran
# 1045     Phillip       Norton
# 1046     Phillip        Power
# 1047     Phillip         Lane
# 1048     Phillip        Power
# 1049     Phillip        Moran
# 1050     Phillip      Quinton
# 1051     Phillip      Quinton
# 1052     Phillip         Lane
# 1053     Phillip       Knight
# 1054     Phillip       Cooper
# 1055     Phillip      Edmonds
# 1056        None         None
# 1057     Phillip      Edwards
# 1058        None         None
# 1059     Phillip      Edmonds
# 1060     Phillip      Edwards
# 1061     Phillip       Knight
# 1062     Phillip      Edwards
# 1063     Phillip       Butler
# 1064     Phillip       Clarke
# 1065     Phillip       Baxter
# 1066     Phillip       Baxter
# 1067     Phillip       Cooper
# 1068     Phillip       Clarke
# 1069     Phillip       Baxter
# 1070     Phillip       Butler
# 1071     Phillip        Bloom
# 1072     Phillip        Bloom
# 1073     Phillip       Cooper
# 1074       Peter       Wright
# 1075      Peyton        Power
# 1076     Phillip        Abbot
# 1077      Peyton     Reynolds
# 1078      Peyton        Power
# 1079       Peter       Wright
# 1080      Peyton        Power
# 1081     Phillip        Abbot
# 1082       Peter       Wright
# 1083      Peyton     Reynolds
# 1084       Peter       Parker
# 1085       Peter     Sherwood
# 1086       Peter     Robinson
# 1087       Peter     Waterson
# 1088       Peter     Sherwood
# 1089       Peter       Parker
# 1090       Peter     Robinson
# 1091       Peter      Simpson
# 1092       Peter       Notman
# 1093       Peter      Simpson
# 1094       Peter     Waterson
# 1095       Peter       Martin
# 1096       Peter      Mcguire
# 1097       Peter       Notman
# 1098       Peter      Mcguire
# 1099       Peter        Lewis
# 1100       Peter       Martin
# 1101       Peter        Lewis
# 1102       Peter         Lynn
# 1103       Peter         Lynn
# 1104       Peter          Lee
# 1105       Peter          Lee
# 1106       Peter       Gordon
# 1107       Peter        Kelly
# 1108       Peter       Gordon
# 1109       Peter         Lane
# 1110       Peter         Lane
# 1111       Peter       Gordon
# 1112       Peter        Kelly
# 1113       Peter       Gordon
# 1114       Peter       Fulton
# 1115       Peter      Edwards
# 1116       Peter         Drew
# 1117       Peter       Fulton
# 1118       Peter       Connor
# 1119       Peter       Fowler
# 1120       Peter         Drew
# 1121       Peter       Fowler
# 1122       Peter       Connor
# 1123       Peter      Edwards
# 1124       Percy     Williams
# 1125       Percy         Yang
# 1126       Peter      Bingham
# 1127       Percy     Williams
# 1128       Peter   Calderwood
# 1129       Peter      Bingham
# 1130       Peter     Campbell
# 1131       Peter     Campbell
# 1132       Percy         Yang
# 1133       Peter   Calderwood
# 1134       Percy        Speed
# 1135       Percy     Thompson
# 1136       Percy        Uddin
# 1137       Percy       Walker
# 1138       Percy        Wilde
# 1139       Percy       Varley
# 1140       Percy       Walker
# 1141       Percy       Varley
# 1142       Percy        Wilde
# 1143       Percy        Uddin
# 1144       Percy     Thompson
# 1145       Percy     Richards
# 1146       Percy     Richards
# 1147       Percy         Roth
# 1148       Percy        Quinn
# 1149       Percy       Powell
# 1150       Percy        Quinn
# 1151       Percy         Roth
# 1152       Percy       Powell
# 1153       Percy        Speed
# 1154       Percy        Osman
# 1155       Percy      Norburn
# 1156       Percy        Osman
# 1157       Percy        Poole
# 1158       Percy       Notman
# 1159       Percy       Notman
# 1160       Percy      Norburn
# 1161       Percy        Poole
# 1162       Percy         Long
# 1163       Percy       Miller
# 1164       Percy       Miller
# 1165       Percy         Long
# 1166       Percy       Newton
# 1167       Percy         John
# 1168       Percy         John
# 1169       Percy       Newton
# 1170       Percy       Irving
# 1171       Percy       Irving
# 1172       Percy      Dempsey
# 1173       Percy    Goldsmith
# 1174       Percy     Hardwick
# 1175       Percy    Goldsmith
# 1176       Percy          Fox
# 1177       Percy       Dillon
# 1178       Percy       Garcia
# 1179       Percy       Dillon
# 1180       Percy     Hardwick
# 1181       Percy       Garcia
# 1182       Percy          Fox
# 1183       Percy       Cooper
# 1184       Percy      Dempsey
# 1185       Percy      Amstead
# 1186       Percy       Dallas
# 1187       Percy     Clarkson
# 1188       Percy       Dallas
# 1189       Percy        Asher
# 1190       Percy        Asher
# 1191       Percy     Clarkson
# 1192       Percy       Cooper
# 1193       Penny       Parker
# 1194       Penny       Parker
# 1195       Percy      Amstead
# 1196       Percy        Abbey
# 1197       Percy        Abbey
# 1198       Percy        Abbey
# 1199    Penelope       Franks
# 1200       Penny        Owens
# 1201       Penny      Gosling
# 1202       Penny        Brett
# 1203       Penny      Gosling
# 1204       Penny        Owens
# 1205       Penny        Brett
# 1206       Paula      Simpson
# 1207      Parker        Yoman
# 1208      Parker       Graham
# 1209      Parker        Yoman
# 1210       Paula      Simpson
# 1211      Parker      Fleming
# 1212      Parker      Fleming
# 1213    Penelope       Franks
# 1214      Parker       Graham
# 1215      Parker       Cooper
# 1216        Owen       Wigley
# 1217        Owen       Wright
# 1218      Parker       Cooper
# 1219        Owen      Yarwood
# 1220        Owen       Wright
# 1221       Paige      Johnson
# 1222       Paige      Johnson
# 1223        Owen       Wright
# 1224        Owen      Yarwood
# 1225        Owen       Wigley
# 1226        Owen        Roman
# 1227        None         None
# 1228        Owen       Wigley
# 1229        None         None
# 1230        None         None
# 1231        Owen      Stanley
# 1232        Owen        Roman
# 1233        Owen      Stanley
# 1234        None         None
# 1235        Owen       Wigley
# 1236        Owen        Quinn
# 1237        Owen     Quinnell
# 1238        Owen         Pope
# 1239        Owen        Reyes
# 1240        Owen     Quinnell
# 1241        Owen       Pearce
# 1242        Owen        Reyes
# 1243        Owen        Quinn
# 1244        Owen        Reyes
# 1245        Owen         Pope
# 1246        Owen       London
# 1247        Owen       Oatway
# 1248        Owen       Palmer
# 1249        Owen      Michael
# 1250        Owen       Palmer
# 1251        Owen       Oatway
# 1252        Owen       Morris
# 1253        Owen       Pearce
# 1254        Owen       Morris
# 1255        Owen      Michael
# 1256        Owen        Locke
# 1257        Owen       Groves
# 1258        Owen       Groves
# 1259        Owen       Jobson
# 1260        Owen        Flack
# 1261        Owen       Jobson
# 1262        Owen        Locke
# 1263        Owen        Flynn
# 1264        Owen        Flynn
# 1265        Owen       London
# 1266        Owen     Clifford
# 1267        Owen       Briggs
# 1268        Owen       Carter
# 1269        Owen        Flack
# 1270        Owen     Clifford
# 1271        Owen       Clarke
# 1272        Owen      Donovan
# 1273        Owen       Briggs
# 1274        Owen      Donovan
# 1275        Owen       Clarke
# 1276        Owen       Carter
# 1277      Oliver    Robertson
# 1278      Olivia    Wilkinson
# 1279      Oliver      Simpson
# 1280      Oliver        Walsh
# 1281      Oliver   Waterhouse
# 1282      Oliver   Waterhouse
# 1283      Oliver        Walsh
# 1284      Oliver      Simpson
# 1285      Olivia    Wilkinson
# 1286      Oliver      Olivier
# 1287      Oliver       Powell
# 1288      Oliver       Powell
# 1289      Oliver        Lucas
# 1290      Oliver      Mcneill
# 1291      Oliver        Lewis
# 1292      Oliver      Olivier
# 1293      Oliver      Mcneill
# 1294      Oliver        Lewis
# 1295      Oliver        Lucas
# 1296      Oliver    Robertson
# 1297      Oliver    Robertson
# 1298      Oliver      Jeffery
# 1299      Oliver       Horton
# 1300      Oliver      Jeffery
# 1301      Oliver       Harper
# 1302        None         None
# 1303      Oliver       Garcia
# 1304      Oliver       Hilton
# 1305      Oliver       Horton
# 1306      Oliver       Hilton
# 1307      Oliver       Harper
# 1308      Oliver       Hilton
# 1309      Oliver       Garcia
# 1310      Oliver        Avery
# 1311       Noemi       Warner
# 1312       Norah      Stewart
# 1313       Noemi       Warner
# 1314      Oliver    Blackburn
# 1315       Noemi         Moss
# 1316        None         None
# 1317      Oliver    Blackburn
# 1318       Norah      Stewart
# 1319      Oliver        Avery
# 1320       Noemi         Moss
# 1321        Noah         Wren
# 1322        Noah      Tyrrell
# 1323        Noah        Woods
# 1324        Noah       Wright
# 1325        Noah       Wright
# 1326        Noah         Wren
# 1327        Noah       Warden
# 1328        Noah        Woods
# 1329        Noah        Woods
# 1330        Noah       Warden
# 1331        None         None
# 1332        None         None
# 1333        Noah       Tanner
# 1334        Noah      Stevens
# 1335        Noah       Tanner
# 1336        Noah      Tyrrell
# 1337        Noah       Tanner
# 1338        Noah       Tanner
# 1339        None         None
# 1340        Noah      Stevens
# 1341        Noah      Simpson
# 1342        Noah      Simpson
# 1343        Noah         Reid
# 1344        Noah     Robinson
# 1345        Noah     Robinson
# 1346        Noah     Robinson
# 1347        Noah         Reid
# 1348        Noah       Redden
# 1349        Noah     Robinson
# 1350        Noah       Redden
# 1351        Noah     Phillips
# 1352        Noah     Phillips
# 1353        Noah       Mccall
# 1354        Noah       Oakley
# 1355        Noah        Osman
# 1356        Noah       Oswald
# 1357        Noah       Oakley
# 1358        Noah       Mccall
# 1359        Noah        Osman
# 1360        Noah       Oswald
# 1361        Noah      Gardner
# 1362        Noah      Jackson
# 1363        Noah       Gordon
# 1364        Noah      Jackson
# 1365        Noah      Gardner
# 1366        Noah       Gordon
# 1367        Noah         King
# 1368        Noah         King
# 1369        Noah       Franks
# 1370        Noah       Button
# 1371        Noah       Brooks
# 1372        Noah        Bowen
# 1373        Noah       Brooks
# 1374        Noah        Bowen
# 1375        Nina          Fox
# 1376        Noah       Butler
# 1377        Nina          Fox
# 1378        Noah       Button
# 1379        Noah       Franks
# 1380        Noah       Butler
# 1381      Nicole      Johnson
# 1382        Nina       Bryant
# 1383        Nick     Robinson
# 1384      Nicole      Johnson
# 1385        Nick      Spencer
# 1386        Nick      Spencer
# 1387        Nick       Wilcox
# 1388        Nick      Vollans
# 1389        Nick      Vollans
# 1390        Nina       Bryant
# 1391        Nick       Wilcox
# 1392        Nick       Morris
# 1393        Nick       Morris
# 1394        Nick       Nelson
# 1395        Nick        Pratt
# 1396        Nick       Nelson
# 1397        Nick     Robinson
# 1398        Nick        Pratt
# 1399        Nick        Mills
# 1400        Nick        Mills
# 1401        Nick       Larkin
# 1402        Nick       Larkin
# 1403        Nick       Larkin
# 1404        Nick        Glynn
# 1405        Nick        Abbot
# 1406        Nick      Edwards
# 1407        Nick       Harper
# 1408        Nick      Edwards
# 1409        Nick        Glynn
# 1410        Nick        Abbot
# 1411        Nick       Harper
# 1412        Nick    Greenwood
# 1413        Nick    Greenwood
# 1414    Nicholas       Wright
# 1415    Nicholas       Wright
# 1416    Nicholas      Vincent
# 1417    Nicholas       Wright
# 1418    Nicholas         Wood
# 1419    Nicholas      Vincent
# 1420    Nicholas      Vincent
# 1421    Nicholas      Vincent
# 1422    Nicholas       Wright
# 1423    Nicholas         Wood
# 1424    Nicholas        Tyler
# 1425    Nicholas     Saunders
# 1426    Nicholas       Stubbs
# 1427    Nicholas        Tyler
# 1428    Nicholas        Smith
# 1429    Nicholas      Stanley
# 1430    Nicholas      Stanley
# 1431    Nicholas        Smith
# 1432    Nicholas     Saunders
# 1433    Nicholas       Stubbs
# 1434    Nicholas         Reid
# 1435    Nicholas        Payne
# 1436    Nicholas         Pitt
# 1437    Nicholas         Reid
# 1438    Nicholas    Robertson
# 1439    Nicholas    Robertson
# 1440    Nicholas        Patel
# 1441    Nicholas         Pitt
# 1442    Nicholas        Payne
# 1443    Nicholas       Nanton
# 1444    Nicholas       Morris
# 1445    Nicholas        Patel
# 1446    Nicholas       Morris
# 1447    Nicholas        Moore
# 1448    Nicholas        Moore
# 1449    Nicholas       Nanton
# 1450    Nicholas      Mcnally
# 1451    Nicholas       Morris
# 1452    Nicholas      Mcnally
# ...
# 6726       Bakery products              Bennett  Route, 6593       460398
# 6727          Animal feeds                  Vine  Vale, 2344       460475
# 6728        Dairy products                Erindale Way, 2759       460840
# 6729                  Meat              Cavendish Road, 8910       461203
# 6730          Animal feeds              Bocking   Lane, 6815       462551
# 6731       Bakery products              Elystan  Drive, 9969       462755
# 6732        Dairy products             Parkfield  Pass, 3458       463710
# 6733      Poultry and fish        Angrave    Crossroad, 5468       463714
# 6734          Animal feeds                 Cloth  Walk, 8315       454575
# 6735      Poultry and fish          Angela   Crossroad, 6774       454638
# 6736        Dairy products                  Union  Way, 7455       460824
# 6737               Milling            Catherine  Alley, 3499       460838
# 6738      Poultry and fish            Champion  Street, 2116       461521
# 6739                  Meat             Andrews  Street, 5003       462406
# 6740        Dairy products                  Ben   Walk, 1866       462758
# 6741                  Meat              Eaglet  Street, 4953       463161
# 6742  Fruit and vegetables            Castle Crossroad, 7881       463708
# 6743       Bakery products               Yoakley Route, 2959       451190
# 6744        Dairy products               Longman   Road, 503       459037
# 6745      Poultry and fish         Caroline  Boulevard, 2558       459039
# 6746      Poultry and fish           Viscount   Street, 1229       459777
# 6747          Animal feeds                 Caedmon  Rue, 660       460694
# 6748  Fruit and vegetables              Canning  Grove, 5927       461530
# 6749  Fruit and vegetables                 Maple Drive, 8249       462655
# 6750      Poultry and fish            St. Johs  Avenue, 3972       462759
# 6751                  Meat                  Cleaver Grove, 8       463158
# 6752      Poultry and fish               Canning  Alley, 442       463701
# 6753      Poultry and fish            Westbourne Grove, 2363       457530
# 6754      Poultry and fish               Beatty  Drive, 4722       459778
# 6755      Poultry and fish         Aberavon  Crossroad, 2995       460385
# 6756                  Meat              Udall   Avenue, 2233       460462
# 6757  Fruit and vegetables            Thoresby   Drive, 9654       460692
# 6758      Poultry and fish          Bellenden   Avenue, 6682       460841
# 6759        Dairy products           Victoria Rise Rue, 9393       461393
# 6760          Animal feeds                 Cloth  Pass, 5624       461802
# 6761               Milling                   Fawn Pass, 9997       462209
# 6762               Milling               Virginia Lane, 4215       462654
# 6763  Fruit and vegetables                 Spruce Road, 3675       463604
# 6764                  Meat               Bethwin  Lane, 3056       448240
# 6765        Dairy products          Longmoore   Street, 4650       454636
# 6766       Bakery products               Cleaver Drive, 9267       457937
# 6767                  Meat                 Canon Drive, 3321       460477
# 6768       Bakery products           Woodland Crossroad, 520       461386
# 6769        Dairy products             Dunstable   Rue, 5922       461529
# 6770          Animal feeds              Cavell   Grove, 2546       463606
# 6771               Milling              Lincoln Avenue, 1258       463651
# 6772          Animal feeds            Unwin  Boulevard, 2230       457506
# 6773                  Meat           Durweston   Route, 2271       458526
# 6774                  Meat                 Elba  Avenue, 210       458530
# 6775       Bakery products            Clissold  Tunnel, 9848       459694
# 6776        Dairy products             Woodland Avenue, 3104       459780
# 6777               Milling               Argyle  Alley, 3319       460846
# 6778  Fruit and vegetables          Longmoore   Tunnel, 1709       461387
# 6779       Bakery products         Castlereagh   Alley, 8020       462403
# 6780        Dairy products             Sheraton   Road, 9290       454140
# 6781  Fruit and vegetables                  Adams  Way, 8068       460617
# 6782               Milling             Blandford  Pass, 3645       461111
# 6783        Dairy products           Caxton  Boulevard, 6191       461902
# 6784      Poultry and fish             Babmaes    Walk, 7193       462410
# 6785          Animal feeds              Timber   Route, 6618       463711
# 6786        Dairy products           Calderwood   Road, 6281       463802
# 6787                  Meat              Magnolia Alley, 5328       451187
# 6788       Bakery products           Balfe   Boulevard, 9646       454591
# 6789       Bakery products              Elgood   Route, 4479       454635
# 6790        Dairy products             Lonsdale  Grove, 9615       455796
# 6791      Poultry and fish         Apothecary   Street, 4860       459768
# 6792        Dairy products               Mariner   Way, 9914       460667
# 6793      Poultry and fish              Gatonby   Grove, 482       461110
# 6794                  Meat         Adelaide  Boulevard, 9725       459034
# 6795                  Meat              Collins  Alley, 7588       460693
# 6796                  Meat                 Durham Walk, 3766       462217
# 6797               Milling              Glenwood Street, 189       462451
# 6798  Fruit and vegetables             Rivervalley Rue, 5227       463501
# 6799  Fruit and vegetables             Monroe Crossroad, 600       454627
# 6800               Milling            Calderwood   Way, 7333       454634
# 6801        Dairy products          Camley   Boulevard, 9374       460671
# 6802          Animal feeds                 Unwin  Vale, 5070       460804
# 6803       Bakery products            Abbotswell  Lane, 8036       462763
# 6804  Fruit and vegetables             Aspen Boulevard, 5572       463851
# 6805        Dairy products                    Lake Way, 2761       454596
# 6806        Dairy products          Rosewood Boulevard, 6293       454629
# 6807      Poultry and fish            Parkfields Grove, 1487       457519
# 6808  Fruit and vegetables         Arundel   Crossroad, 6857       459774
# 6809       Bakery products                Bell    Vale, 3215       460394
# 6810      Poultry and fish                  Ashley Rue, 1223       462801
# 6811               Milling            Cliffords  Route, 2809       463605
# 6812       Bakery products            Chancellor  Road, 5060       460928
# 6813  Fruit and vegetables               Enford   Road, 8710       461730
# 6814       Bakery products             Castile  Tunnel, 2910       461734
# 6815       Bakery products             Blomfield  Road, 8583       461753
# 6816                  Meat                 Howard Vale, 2030       462806
# 6817  Fruit and vegetables                 Balfe   Way, 1886       463602
# 6818               Milling              Bocking   Road, 4673       457935
# 6819               Milling                  Lake Route, 2321       458535
# 6820  Fruit and vegetables                Wadham  Lane, 1586       460400
# 6821      Poultry and fish             Andrews  Avenue, 5129       460839
# 6822                  Meat             Bishop   Avenue, 7293       461107
# 6823  Fruit and vegetables              Garfield Grove, 8005       461727
# 6824        Dairy products             English   Route, 5772       462404
# 6825  Fruit and vegetables            Chartham  Tunnel, 8487       457527
# 6826                  Meat                Arthur  Alley, 539       460237
# 6827       Bakery products              Carolina  Lane, 5710       461391
# 6828        Dairy products            Fairholt   Grove, 3647       461533
# 6829        Dairy products               Blean   Drive, 3106       461733
# 6830          Animal feeds                Balham   Rue, 7990       462216
# 6831        Dairy products                Camley   Lane, 218       462225
# 6832        Dairy products                   West Hill, 8170       458534
# 6833               Milling            Falconberg   Pass, 820       460697
# 6834               Milling              Empress  Grove, 1940       462214
# 6835               Milling        St. Pauls  Boulevard, 1016       462412
# 6836                  Meat               Blean   Drive, 7238       463707
# 6837      Poultry and fish             Marischal  Hill, 9152       463755
# 6838          Animal feeds          Timber   Crossroad, 4792       460615
# 6839        Dairy products               Clarks  Grove, 5747       461723
# 6840               Milling                Carol   Lane, 6086       461759
# 6841  Fruit and vegetables                 Oxford Vale, 9496       462213
# 6842       Bakery products                 Clyde Alley, 3440       462413
# 6843  Fruit and vegetables              Sheffield Lane, 6813       462761
# 6844               Milling             St. Pauls  Pass, 4072       462766
# 6845      Poultry and fish                Gavel   Lane, 2347       463713
# 6846  Fruit and vegetables               Caslon   Pass, 4367       461396
# 6847        Dairy products                Bethwin  Rue, 1089       461398
# 6848                  Meat          King William  Lane, 4620       461718
# 6849        Dairy products               Ellerslie Way, 4453       461729
# 6850          Animal feeds              Berriman  Road, 8430       461737
# 6851        Dairy products        Thomas Doyle   Alley, 2351       462053
# 6852        Dairy products            Longman   Avenue, 7675       462652
# 6853  Fruit and vegetables                      King Rue, 40       463753
# 6854       Bakery products           Camden  Boulevard, 8626       455780
# 6855          Animal feeds           Thomas More   Way, 3840       457921
# 6856  Fruit and vegetables             Blomfield  Walk, 4109       457943
# 6857      Poultry and fish            Littlebury  Road, 9105       459779
# 6858                  Meat                Burton  Pass, 1341       459785
# 6859       Bakery products               Thurloe   Rue, 3037       460397
# 6860      Poultry and fish                 Bond Tunnel, 9445       462201
# 6861                  Meat             Gautrey  Tunnel, 2363       462756
# 6862                  Meat                 Oxford Vale, 2793       463154
# 6863        Dairy products               Gautrey  Lane, 8442       463160
# 6864        Dairy products            Church Crossroad, 4530       456924
# 6865       Bakery products             Battis   Street, 4078       457528
# 6866       Bakery products               Camley   Vale, 7558       457529
# 6867          Animal feeds             Chatfield  Lane, 8934       457623
# 6868        Dairy products              Bell    Avenue, 8626       459035
# 6869  Fruit and vegetables               Mariner  Pass, 3109       460703
# 6870          Animal feeds             Maple Crossroad, 3053       461392
# 6871  Fruit and vegetables              Victoria  Road, 6460       461531
# 6872                  Meat                Apostle  Rue, 4842       462223
# 6873  Fruit and vegetables               Camera  Grove, 3440       463159
# 6874  Fruit and vegetables              Canning  Alley, 8240       448239
# 6875               Milling               Vincent  Walk, 7448       457944
# 6876      Poultry and fish         Fieldstone Boulevard, 161       459036
# 6877          Animal feeds             Caroline  Alley, 4295       460616
# 6878        Dairy products             Parkfield  Lane, 7051       460669
# 6879        Dairy products         Apsley    Crossroad, 8069       460689
# 6880          Animal feeds              Ensign   Grove, 4063       460849
# 6881               Milling               Kilner   Tunnel, 13       461114
# 6882        Dairy products              Calvin   Route, 3850       461725
# 6883                  Meat                Baltic  Pass, 1138       463715
# 6884       Bakery products          Bekesbourne   Vale, 9211       454993
# 6885      Poultry and fish                 Unwin  Walk, 5657       456923
# 6886               Milling             Addison  Avenue, 1679       456925
# 6887               Milling               Chantry   Rue, 3749       459015
# 6888          Animal feeds              Tilson  Street, 6362       460931
# 6889      Poultry and fish               Berry  Avenue, 1516       462219
# 6890  Fruit and vegetables              Duthie   Route, 5706       463157
# 6891  Fruit and vegetables                   Blake  Way, 792       463706
# 6892               Milling                Glenwood Way, 2625       463709
# 6893        Dairy products             Caroline  Grove, 6858       463718
# 6894          Animal feeds            Dunstable   Lane, 4747       458529
# 6895        Dairy products            Chambers  Avenue, 9202       460875
# 6896       Bakery products                  Spruce Way, 1202       461720
# 6897        Dairy products                 Cliff  Lane, 5912       462805
# 6898        Dairy products              Wadham  Avenue, 8929       463607
# 6899                  Meat            Geary   Crossroad, 881       448233
# 6900      Poultry and fish                Becklow  Rue, 5646       460605
# 6901        Dairy products         Amwell    Boulevard, 2333       460843
# 6902               Milling             Sherlock   Hill, 1032       461115
# 6903  Fruit and vegetables                   Aspen Walk, 241       462656
# 6904       Bakery products               Thrale   Lane, 1299       462803
# 6905               Milling            Arundel   Tunnel, 8299       463608
# 6906                  Meat               Durham Street, 9119       463712
# 6907       Bakery products          Longleigh   Street, 1777       455776
# 6908          Animal feeds              Paris   Tunnel, 8579       457532
# 6909  Fruit and vegetables              Bicknell  Hill, 1202       458532
# 6910                  Meat             Dunstans  Grove, 6712       460479
# 6911       Bakery products           Clerkenwell Grove, 3422       460695
# 6912  Fruit and vegetables                Garfield Way, 6081       461732
# 6913       Bakery products             Fairholt   Pass, 4944       461736
# 6914  Fruit and vegetables                Wake  Street, 9405       462408
# 6915      Poultry and fish           Beaconsfield  Rue, 9014       454637
# 6916          Animal feeds           Collingwood  Lane, 7643       459690
# 6917      Poultry and fish          Charnwood   Avenue, 4489       460698
# 6918               Milling             Earl Rise Drive, 2400       460842
# 6919       Bakery products                Mariner  Rue, 6735       460845
# 6920                  Meat          Thomas More   Walk, 6363       460848
# 6921  Fruit and vegetables                Lincoln Hill, 4716       462224
# 6922                  Meat             Longman   Drive, 5228       462762
# 6923                  Meat      Hickory Lane Boulevard, 8003       455788
# 6924          Animal feeds           Cleaver Crossroad, 3832       457945
# 6925  Fruit and vegetables        Fieldstone Boulevard, 9817       457946
# 6926               Milling             Rivervalley Rue, 3207       461738
# 6927      Poultry and fish             Chambers  Route, 5482       462218
# 6928          Animal feeds        Arlington  Crossroad, 7876       462411
# 6929  Fruit and vegetables               Camdale  Vale, 9951       463716
# 6930       Bakery products               Virginia Lane, 7272       463717
# 6931  Fruit and vegetables                 Cato   Hill, 5704       463801
# 6932       Bakery products            Howard Crossroad, 9998       454595
# 6933          Animal feeds                  Walnut Rue, 3859       454631
# 6934       Bakery products             Kimberley  Pass, 3455       457622
# 6935  Fruit and vegetables            Yorkshire  Alley, 5843       461395
# Data saved to contacts_data_collect.csv

# %% [markdown]
# 2. Data Animation:
#    - Tools.car(0) is a function (likely defined in your code) that provides an animation or message indicating that data import has completed successfully.

# %%
Tools.car(0)  # Indicate data import with car animation
# Out:
# -------─────▄▌▐▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▀▌ ---------------------------------
# -------───▄▄██▌█ ..Data Imported..      ---------------------------------
# -------▄▄▄▌▐██▌█ ................       ---------------------------------
# -------███████▌█▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▌ ---------------------------------
# -------▀(@)▀▀▀▀▀▀▀(@)(@)▀▀▀▀▀▀▀▀▀▀▀▀(@)▀---------------------------------

# %% [markdown]
# 3. Transform Data:
#    - Tools.car(2) starts an animation or message indicating that data transformation is in progress.
#    - The transform() function from pipeline processes data_list, performing tasks like cleaning data and merging duplicates.
#    - The transformed data is saved to "contacts_data_result.csv" for future use.

# %%
Tools.car(2)  # Indicate data transform
# Transform the data and save the transformed DataFrame
data_frame = pipeline.transform(data_list)
data_frame.to_csv("contacts_data_result.csv", index=False)
print("Data saved to contacts_data_result.csv")

# %%
# Load data from a CSV file into a DataFrame
# data_frame = pd.read_csv("contacts_data_result.csv")

# %% [markdown]
# Analysis 1: Distribution of Contacts by Country
#
# Objective: To visualize the number of contacts from each country.
# Process:
# - Uses `value_counts()` on the 'country' column of the DataFrame to count the number of contacts per country.
# - Generates a bar chart using `plot(kind='bar', color='skyblue')` to display the distribution of contacts by country visually.
# Labels:
# - The x-axis is labeled "Country," and the y-axis is labeled "Number of Contacts."
# - The x-axis labels are rotated by 45 degrees for readability.

# %%
# Analysis 1: Distribution of contacts by country
country_counts = df['country'].value_counts()
plt.figure(figsize=(10, 6))
country_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of Contacts by Country')
plt.xlabel('Country')
plt.ylabel('Number of Contacts')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Analysis 3: Contact Creation Trend Over Time
#
# Objective: To examine the trend of contact creation over time, aggregated by month.
# Process:
# - Converts the 'technical_test___create_date' column to datetime format for date manipulation.
# - Groups dates by month using `dt.to_period('M')`, and calculates the number of contacts created per month with `value_counts()`.
# - Generates a line plot to display the trend of contact creation over time.
# Labels:
# - The x-axis is labeled "Month," and the y-axis is labeled "Number of Contacts Created."
# - The x-axis labels are rotated by 45 degrees for readability.

# %%
# Analysis 2: Top email domains by contact count
# Extract the email domain
df['email_domain'] = df['raw_email'].apply(lambda x: x.split('@')[-1] if pd.notna(x) else None)

# Count the frequency of each email domain
domain_counts = df['email_domain'].value_counts()

# Create bar chart of the most common email domains
plt.figure(figsize=(10, 6))
domain_counts.plot(kind='bar', color='salmon')
plt.title('Top Email Domains by Contact Count')
plt.xlabel('Email Domain')
plt.ylabel('Number of Contacts')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Analysis 3: Contact Creation Trend Over Time
#
# Objective: To examine the trend of contact creation over time, aggregated by month.
# Process:
# - Converts the 'technical_test___create_date' column to datetime format for date manipulation.
# - Groups dates by month using `dt.to_period('M')`, and calculates the number of contacts created per month with `value_counts()`.
# - Generates a line plot to display the trend of contact creation over time.
# Labels:
# - The x-axis is labeled "Month," and the y-axis is labeled "Number of Contacts Created."
# - The x-axis labels are rotated by 45 degrees for readability.

# %%
# Analysis 3: Contact creation trend over time
df['technical_test___create_date'] = pd.to_datetime(df['technical_test___create_date'])
date_counts = df['technical_test___create_date'].dt.to_period('M').value_counts().sort_index()
plt.figure(figsize=(12, 6))
date_counts.plot(kind='line', marker='o', color='green')
plt.title('Trend of Contact Creation Dates')
plt.xlabel('Month')
plt.ylabel('Number of Contacts Created')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 4. Load Data into HubSpot:
#    - This part reads the transformed data from the CSV file into a new DataFrame (data_frame).
#    - The load() method from pipeline then pushes the transformed data to HubSpot.
#    - Tools.car(1) displays an animation or message confirming that data export is complete.

# %%
# Load the transformed data into HubSpot
pipeline.load(data_frame)
Tools.car(1)  # Indicate data export with car animation
